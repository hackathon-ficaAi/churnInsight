# %% [markdown]
# <a href="https://colab.research.google.com/github/hackathon-ficaAi/churnInsight/blob/data-science/jupyter_notebook/rascunho.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install feature_engine
# Out:
# Collecting feature_engine
#   Downloading feature_engine-1.9.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.12/dist-packages (from feature_engine) (2.0.2)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from feature_engine) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from feature_engine) (1.6.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from feature_engine) (1.16.3)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from feature_engine) (0.14.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->feature_engine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->feature_engine) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->feature_engine) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->feature_engine) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.0->feature_engine) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.11.1->feature_engine) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.11.1->feature_engine) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->feature_engine) (1.17.0)
# Downloading feature_engine-1.9.3-py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.0/230.0 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: feature_engine
# Successfully installed feature_engine-1.9.3

# %%
import pandas as pd
import numpy as np
# Bibliotecas para gerar gráficos
import matplotlib.pyplot as plt
import seaborn as sns
# Encode e preprocessing
from sklearn.pipeline import Pipeline
from sklearn.compose import make_column_transformer, ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from feature_engine import discretisation, encoding
# Modelos de classificação
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn import linear_model
from sklearn.ensemble import RandomForestClassifier
# Métricas
from sklearn import metrics
# serialização
import joblib

# %%
# Colocando os dados traduzidos em um DataFrame
url = 'https://raw.githubusercontent.com/hackathon-ficaAi/churnInsight/refs/heads/main/data/treino.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    id_cliente  idade localizacao  tipo_assinatura plano_pagamento  \
# 0           1     60       Maine  familia premium           anual
# 1           2     69  California           basico          mensal
# 2           3     36   Nebrasksa          premium           anual
# 3           4     73     Montana          premium          mensal
# 4           5     58    Virginia  familia premium           anual
#
#    num_pausas_assinatura metodo_pagamento chamados_suporte data_inscricao  \
# 0                      0          credito           nenhum      6/22/2013
# 1                      1          credito           poucos      5/29/2018
# 2                      1           debito           nenhum      12/9/2016
# 3                      0           debito           nenhum      8/30/2017
# 4                      0          credito  muito frequente       8/9/2013
#
#    horas_semanais  tempo_medio_sessao  taxa_skip_musica  \
# 0        8.231109            0.880944              0.10
# 1       13.109191            2.580870              0.60
# 2       19.617798            0.935676              0.21
# 3       26.023783            0.878620              0.15
# 4       17.876039            0.496145              0.01
#
#    musicas_tocadas_semana  musicas_unicas_semana  num_artistas_favoritos  \
# 0                     148                     93                       8
# 1                     158                     80                       4
# 2                     319                    188                       5
# 3                     375                    354                       6
# 4                     239                    124                       8
#
#    num_amigos_plataforma  num_playlists_criadas  num_playlists_compartilhadas  \
# 0                     74                      8                             4
# 1                     54                     12                             3
# 2                     89                     11                             3
# 3                     45                      8                             4
# 4                     69                     12                             6
#
#    notificacoes_clicadas  churned
# 0                      0        0
# 1                     54        0
# 2                    156        0
# 3                    149        0
# 4                      0        0

# %%
# Juntando data de inscrição para inscrição Anual
df['data_inscricao'] = pd.to_datetime(df['data_inscricao'])
df['ano_inscricao'] = df['data_inscricao'].dt.to_period('A')
df['ano_inscricao'].value_counts().sort_index()
# Out:
# /tmp/ipython-input-740319196.py:3: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'Y' instead.
#   df['ano_inscricao'] = df['data_inscricao'].dt.to_period('A')
# ano_inscricao
# 2013    1405
# 2014    1357
# 2015    1310
# 2016    1376
# 2017    1374
# 2018    1422
# 2019    1380
# 2020    1356
# 2021    1347
# 2022     173
# Freq: Y-DEC, Name: count, dtype: int64

# %%
# Criando uma série temporal - com os anos de 2022 e 2021
ultimo_ano = df['ano_inscricao'].max()
oot = df[df['ano_inscricao'] >= (ultimo_ano - 1)].copy()
oot
# Out:
#        id_cliente  idade    localizacao  tipo_assinatura plano_pagamento  \
# 16             17     59   North Dakota           basico          mensal
# 21             22     51          Idaho           basico           anual
# 24             25     41        Vermont  familia premium          mensal
# 34             35     68        Alabama           basico           anual
# 38             39     28          Maine        estudante           anual
# ...           ...    ...            ...              ...             ...
# 12460       12461     21          Idaho        estudante           anual
# 12467       12468     52        Alabama          premium           anual
# 12475       12476     32        Alabama          premium          mensal
# 12478       12479     79       New York  familia premium           anual
# 12495       12496     70  West Virginia  familia premium           anual
#
#        num_pausas_assinatura metodo_pagamento chamados_suporte data_inscricao  \
# 16                         1          credito           poucos     2021-08-18
# 21                         0          credito           alguns     2021-09-25
# 24                         1          credito           poucos     2021-04-19
# 34                         1           debito           poucos     2022-01-01
# 38                         2            venmo           nenhum     2021-12-16
# ...                      ...              ...              ...            ...
# 12460                      0           debito  muito frequente     2021-08-31
# 12467                      1           debito           nenhum     2021-04-05
# 12475                      1          credito           nenhum     2021-07-30
# 12478                      1           debito           muitos     2021-10-16
# 12495                      2           debito           muitos     2021-02-16
#
#        horas_semanais  ...  taxa_skip_musica  musicas_tocadas_semana  \
# 16           4.060661  ...              0.32                      55
# 21          25.196482  ...              0.87                     427
# 24          20.304050  ...              0.86                     340
# 34           0.912640  ...              0.75                      13
# 38          14.852901  ...              0.40                     202
# ...               ...  ...               ...                     ...
# 12460       10.243765  ...              0.04                     181
# 12467        2.983817  ...              0.67                      52
# 12475       29.752390  ...              0.37                     473
# 12478       29.352786  ...              0.46                     526
# 12495       24.384884  ...              0.25                     306
#
#        musicas_unicas_semana  num_artistas_favoritos  num_amigos_plataforma  \
# 16                        39                       5                     57
# 21                       398                       6                     57
# 24                       216                       5                     71
# 34                         7                       2                     27
# 38                       185                       6                     83
# ...                      ...                     ...                    ...
# 12460                    155                       5                     97
# 12467                     48                       5                     58
# 12475                    357                       5                     82
# 12478                    407                       9                     28
# 12495                    241                       4                     30
#
#        num_playlists_criadas  num_playlists_compartilhadas  \
# 16                        15                            15
# 21                         6                             2
# 24                        11                             3
# 34                         8                             3
# 38                         7                             2
# ...                      ...                           ...
# 12460                      7                             7
# 12467                     11                             6
# 12475                      9                             5
# 12478                     10                            10
# 12495                     17                             9
#
#        notificacoes_clicadas  churned  ano_inscricao
# 16                        20        0           2021
# 21                        17        0           2021
# 24                         2        0           2021
# 34                        19        1           2022
# 38                        20        0           2021
# ...                      ...      ...            ...
# 12460                     40        0           2021
# 12467                     23        0           2021
# 12475                     19        0           2021
# 12478                      0        0           2021
# 12495                      1        0           2021
#
# [1520 rows x 21 columns]

# %%
# Criando uma base de treino sem os anos de 2022 e 2021
df_train = df[df['ano_inscricao'] < (ultimo_ano - 1)].copy()
df_train
# Out:
#        id_cliente  idade localizacao  tipo_assinatura plano_pagamento  \
# 0               1     60       Maine  familia premium           anual
# 1               2     69  California           basico          mensal
# 2               3     36   Nebrasksa          premium           anual
# 3               4     73     Montana          premium          mensal
# 4               5     58    Virginia  familia premium           anual
# ...           ...    ...         ...              ...             ...
# 12494       12495     36    Virginia  familia premium           anual
# 12496       12497     64   Wisconsin  familia premium           anual
# 12497       12498     21  California           basico          mensal
# 12498       12499     70    New York  familia premium           anual
# 12499       12500     55     Montana          premium          mensal
#
#        num_pausas_assinatura metodo_pagamento chamados_suporte data_inscricao  \
# 0                          0          credito           nenhum     2013-06-22
# 1                          1          credito           poucos     2018-05-29
# 2                          1           debito           nenhum     2016-12-09
# 3                          0           debito           nenhum     2017-08-30
# 4                          0          credito  muito frequente     2013-08-09
# ...                      ...              ...              ...            ...
# 12494                      2          credito           nenhum     2017-06-24
# 12496                      1           debito           alguns     2020-11-06
# 12497                      2           debito           nenhum     2019-08-05
# 12498                      2            venmo           alguns     2015-06-26
# 12499                      2          credito           alguns     2016-10-06
#
#        horas_semanais  ...  taxa_skip_musica  musicas_tocadas_semana  \
# 0            8.231109  ...              0.10                     148
# 1           13.109191  ...              0.60                     158
# 2           19.617798  ...              0.21                     319
# 3           26.023783  ...              0.15                     375
# 4           17.876039  ...              0.01                     239
# ...               ...  ...               ...                     ...
# 12494       18.122941  ...              0.16                     246
# 12496       17.397833  ...              0.41                     225
# 12497       16.543161  ...              0.28                     209
# 12498        1.691503  ...              0.28                      22
# 12499       11.327005  ...              0.41                     217
#
#        musicas_unicas_semana  num_artistas_favoritos  num_amigos_plataforma  \
# 0                         93                       8                     74
# 1                         80                       4                     54
# 2                        188                       5                     89
# 3                        354                       6                     45
# 4                        124                       8                     69
# ...                      ...                     ...                    ...
# 12494                    124                       6                     88
# 12496                    163                       4                     43
# 12497                    164                       3                    102
# 12498                     14                       3                     43
# 12499                    139                       3                     54
#
#        num_playlists_criadas  num_playlists_compartilhadas  \
# 0                          8                             4
# 1                         12                             3
# 2                         11                             3
# 3                          8                             4
# 4                         12                             6
# ...                      ...                           ...
# 12494                      9                             9
# 12496                     14                             5
# 12497                     15                             8
# 12498                     10                             3
# 12499                      8                             3
#
#        notificacoes_clicadas  churned  ano_inscricao
# 0                          0        0           2013
# 1                         54        0           2018
# 2                        156        0           2016
# 3                        149        0           2017
# 4                          0        0           2013
# ...                      ...      ...            ...
# 12494                      2        0           2017
# 12496                      0        0           2020
# 12497                     58        0           2019
# 12498                      0        0           2015
# 12499                    151        0           2016
#
# [10980 rows x 21 columns]

# %%
# Separando target de features
target = 'churned'

categoricals = [
    'tipo_assinatura',
    'plano_pagamento',
    'metodo_pagamento',
    'chamados_suporte',
    'localizacao'
]

numericals = [
    col for col in df_train.columns
    if col not in categoricals + [target,
                                   'ano_inscricao','id_cliente']
]

X,y= df_train[categoricals + numericals], df_train[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    random_state=42,
                                                    test_size=0.2,
                                                    stratify=y)

# %%
# EXPLORE
def criar_features(df:pd.DataFrame):
    df = df.copy()
    # Cria uma coluna que indica se usuarios clicou em pelo menos uma notificação ou não
    df['clicou_notificacao'] = (df['notificacoes_clicadas'] > 0).astype(int)
    # Aplicando log para tratar inflação de zeros
    df['log_notificacoes'] = np.log1p(df['notificacoes_clicadas'])
    # Cria uma coluna com a relação de taxas de musicas unicas por semana
    df['taxa_musicas_unicas'] = df['musicas_unicas_semana']/df['musicas_tocadas_semana']
    # Fazendo uma coluna de "tempo de casa" para indicar quantos dias se passaram desde a inscrição do usuário
    data_referencia = df['data_inscricao'].max()
    df['data_inscricao'] = (data_referencia - df['data_inscricao']).dt.days
    return df

# %%
# Análise de comportamento por churn com variáveis numéricas
X_train.isna().sum().sort_values(ascending=False)

df_analise = X_train.copy()
df_analise = criar_features(df_analise)
feat_num = list(set(df_analise.columns) - set(categoricals))

df_analise[target] = y_train
sumario = df_analise[feat_num + [target]].groupby(by=target).agg(["mean","median"]).T

# %%
sumario['diff_abs'] = sumario[0] - sumario[1]
sumario['diff_rel'] = sumario[0]/sumario[1]
sumario.sort_values(by=['diff_rel'], ascending=False)
# Out:
# churned                                        0            1   diff_abs  \
# taxa_skip_musica             median     0.330000     0.310000   0.020000
#                              mean       0.374382     0.353393   0.020989
# tempo_medio_sessao           mean       1.550831     1.492637   0.058194
# num_pausas_assinatura        mean       1.005069     0.968645   0.036424
# num_amigos_plataforma        median    64.000000    62.000000   2.000000
# musicas_unicas_semana        median   158.000000   156.000000   2.000000
# data_inscricao               mean    1459.646686  1442.511758  17.134928
# num_amigos_plataforma        mean      63.589659    63.161254   0.428405
# num_playlists_criadas        mean      11.845900    11.789474   0.056427
# clicou_notificacao           mean       0.866303     0.862262   0.004041
# log_notificacoes             mean       2.928075     2.920820   0.007255
# musicas_unicas_semana        mean     166.826765   166.493841   0.332924
# taxa_musicas_unicas          mean       0.690532     0.689546   0.000986
# idade                        mean      51.609555    51.597984   0.011571
# tempo_medio_sessao           median     1.272250     1.272181   0.000069
# num_artistas_favoritos       median     6.000000     6.000000   0.000000
# idade                        median    52.000000    52.000000   0.000000
# num_playlists_compartilhadas median     5.000000     5.000000   0.000000
# num_pausas_assinatura        median     1.000000     1.000000   0.000000
# clicou_notificacao           median     1.000000     1.000000   0.000000
# num_playlists_criadas        median    11.000000    11.000000   0.000000
# musicas_tocadas_semana       mean     240.478773   241.154535  -0.675762
# horas_semanais               mean      15.644084    15.723524  -0.079440
# log_notificacoes             median     3.891820     3.912023  -0.020203
# taxa_musicas_unicas          median     0.666667     0.670455  -0.003788
# num_artistas_favoritos       mean       5.591940     5.639418  -0.047478
# num_playlists_compartilhadas mean       6.246864     6.353863  -0.107000
# notificacoes_clicadas        median    48.000000    49.000000  -1.000000
# data_inscricao               median  1441.000000  1476.000000 -35.000000
# notificacoes_clicadas        mean      61.007604    62.547592  -1.539989
# musicas_tocadas_semana       median   236.000000   244.000000  -8.000000
# horas_semanais               median    15.766639    16.421962  -0.655324
#
# churned                              diff_rel
# taxa_skip_musica             median  1.064516
#                              mean    1.059393
# tempo_medio_sessao           mean    1.038988
# num_pausas_assinatura        mean    1.037603
# num_amigos_plataforma        median  1.032258
# musicas_unicas_semana        median  1.012821
# data_inscricao               mean    1.011879
# num_amigos_plataforma        mean    1.006783
# num_playlists_criadas        mean    1.004786
# clicou_notificacao           mean    1.004687
# log_notificacoes             mean    1.002484
# musicas_unicas_semana        mean    1.002000
# taxa_musicas_unicas          mean    1.001430
# idade                        mean    1.000224
# tempo_medio_sessao           median  1.000054
# num_artistas_favoritos       median  1.000000
# idade                        median  1.000000
# num_playlists_compartilhadas median  1.000000
# num_pausas_assinatura        median  1.000000
# clicou_notificacao           median  1.000000
# num_playlists_criadas        median  1.000000
# musicas_tocadas_semana       mean    0.997198
# horas_semanais               mean    0.994948
# log_notificacoes             median  0.994836
# taxa_musicas_unicas          median  0.994350
# num_artistas_favoritos       mean    0.991581
# num_playlists_compartilhadas mean    0.983160
# notificacoes_clicadas        median  0.979592
# data_inscricao               median  0.976287
# notificacoes_clicadas        mean    0.975379
# musicas_tocadas_semana       median  0.967213
# horas_semanais               median  0.960095

# %%
X_train = criar_features(X_train)
arvore = tree.DecisionTreeClassifier(random_state=42)
arvore.fit(X_train[feat_num],y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
plt.figure(dpi=700)
tree.plot_tree(arvore,
               feature_names=X_train[feat_num].columns,
               filled=True,
               class_names=[str(i) for i in arvore.classes_])
# Out:
# [Text(0.8129164546384019, 0.9875, 'notificacoes_clicadas <= 404.5\ngini = 0.183\nsamples = 8784\nvalue = [7891, 893]\nclass = 0'),
#  Text(0.8116154300815633, 0.9625, 'tempo_medio_sessao <= 3.719\ngini = 0.182\nsamples = 8782\nvalue = [7891.0, 891.0]\nclass = 0'),
#  Text(0.8122659423599826, 0.9750000000000001, 'True  '),
#  Text(0.648090085240375, 0.9375, 'tempo_medio_sessao <= 3.717\ngini = 0.186\nsamples = 8333\nvalue = [7470, 863]\nclass = 0'),
#  Text(0.6467890606835366, 0.9125, 'taxa_skip_musica <= 0.485\ngini = 0.186\nsamples = 8332\nvalue = [7470, 862]\nclass = 0'),
#  Text(0.5293874723540223, 0.8875, 'taxa_musicas_unicas <= 0.866\ngini = 0.194\nsamples = 6092\nvalue = [5429, 663]\nclass = 0'),
#  Text(0.3593754615603782, 0.8625, 'taxa_musicas_unicas <= 0.866\ngini = 0.201\nsamples = 5163\nvalue = [4577, 586]\nclass = 0'),
#  Text(0.3580744370035397, 0.8375, 'data_inscricao <= 2475.0\ngini = 0.201\nsamples = 5161\nvalue = [4577, 584]\nclass = 0'),
#  Text(0.15451283562685497, 0.8125, 'taxa_musicas_unicas <= 0.529\ngini = 0.209\nsamples = 4359\nvalue = [3843, 516]\nclass = 0'),
#  Text(0.05025207350788746, 0.7875, 'tempo_medio_sessao <= 1.695\ngini = 0.155\nsamples = 590\nvalue = [540, 50]\nclass = 0'),
#  Text(0.034802406895430155, 0.7625, 'tempo_medio_sessao <= 1.687\ngini = 0.197\nsamples = 398\nvalue = [354, 44]\nclass = 0'),
#  Text(0.033501382338591644, 0.7375, 'musicas_unicas_semana <= 188.5\ngini = 0.193\nsamples = 397\nvalue = [354, 43]\nclass = 0'),
#  Text(0.03220035778175313, 0.7125, 'horas_semanais <= 16.51\ngini = 0.216\nsamples = 349\nvalue = [306, 43]\nclass = 0'),
#  Text(0.018214343795739146, 0.6875, 'notificacoes_clicadas <= 71.5\ngini = 0.163\nsamples = 279\nvalue = [254, 25]\nclass = 0'),
#  Text(0.009757684176288828, 0.6625, 'taxa_skip_musica <= 0.22\ngini = 0.102\nsamples = 186\nvalue = [176, 10]\nclass = 0'),
#  Text(0.008456659619450317, 0.6375, 'gini = 0.0\nsamples = 80\nvalue = [80, 0]\nclass = 0'),
#  Text(0.011058708733127337, 0.6375, 'num_playlists_criadas <= 9.5\ngini = 0.171\nsamples = 106\nvalue = [96, 10]\nclass = 0'),
#  Text(0.0065051227841925515, 0.6125, 'num_amigos_plataforma <= 71.5\ngini = 0.334\nsamples = 33\nvalue = [26, 7]\nclass = 0'),
#  Text(0.003903073670515531, 0.5875, 'data_inscricao <= 611.0\ngini = 0.091\nsamples = 21\nvalue = [20, 1]\nclass = 0'),
#  Text(0.002602049113677021, 0.5625, 'data_inscricao <= 508.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.0013010245568385104, 0.5375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.003903073670515531, 0.5375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.005204098227354042, 0.5625, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = 0'),
#  Text(0.009107171897869573, 0.5875, 'num_amigos_plataforma <= 89.0\ngini = 0.5\nsamples = 12\nvalue = [6, 6]\nclass = 0'),
#  Text(0.007806147341031062, 0.5625, 'taxa_skip_musica <= 0.455\ngini = 0.444\nsamples = 9\nvalue = [3, 6]\nclass = 1'),
#  Text(0.0065051227841925515, 0.5375, 'musicas_unicas_semana <= 96.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = 1'),
#  Text(0.005204098227354042, 0.5125, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = 1'),
#  Text(0.007806147341031062, 0.5125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.009107171897869573, 0.5375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.010408196454708083, 0.5625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.015612294682062124, 0.6125, 'num_amigos_plataforma <= 45.0\ngini = 0.079\nsamples = 73\nvalue = [70, 3]\nclass = 0'),
#  Text(0.014311270125223614, 0.5875, 'num_amigos_plataforma <= 34.5\ngini = 0.291\nsamples = 17\nvalue = [14, 3]\nclass = 0'),
#  Text(0.013010245568385103, 0.5625, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = 0'),
#  Text(0.015612294682062124, 0.5625, 'taxa_skip_musica <= 0.36\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = 1'),
#  Text(0.014311270125223614, 0.5375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.016913319238900635, 0.5375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.016913319238900635, 0.5875, 'gini = 0.0\nsamples = 56\nvalue = [56, 0]\nclass = 0'),
#  Text(0.02667100341518946, 0.6625, 'tempo_medio_sessao <= 1.466\ngini = 0.271\nsamples = 93\nvalue = [78, 15]\nclass = 0'),
#  Text(0.02406895430151244, 0.6375, 'tempo_medio_sessao <= 0.053\ngini = 0.233\nsamples = 89\nvalue = [77, 12]\nclass = 0'),
#  Text(0.02276792974467393, 0.6125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.02536997885835095, 0.6125, 'num_amigos_plataforma <= 104.5\ngini = 0.203\nsamples = 87\nvalue = [77, 10]\nclass = 0'),
#  Text(0.02406895430151244, 0.5875, 'notificacoes_clicadas <= 110.5\ngini = 0.187\nsamples = 86\nvalue = [77, 9]\nclass = 0'),
#  Text(0.02276792974467393, 0.5625, 'musicas_unicas_semana <= 76.5\ngini = 0.315\nsamples = 46\nvalue = [37, 9]\nclass = 0'),
#  Text(0.019515368352577656, 0.5375, 'taxa_skip_musica <= 0.005\ngini = 0.161\nsamples = 34\nvalue = [31, 3]\nclass = 0'),
#  Text(0.018214343795739146, 0.5125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.020816392909416167, 0.5125, 'num_playlists_compartilhadas <= 2.5\ngini = 0.114\nsamples = 33\nvalue = [31, 2]\nclass = 0'),
#  Text(0.018214343795739146, 0.4875, 'notificacoes_clicadas <= 81.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.016913319238900635, 0.4625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.019515368352577656, 0.4625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.023418442023093185, 0.4875, 'taxa_skip_musica <= 0.315\ngini = 0.062\nsamples = 31\nvalue = [30, 1]\nclass = 0'),
#  Text(0.022117417466254674, 0.4625, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]\nclass = 0'),
#  Text(0.024719466579931695, 0.4625, 'musicas_unicas_semana <= 9.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = 0'),
#  Text(0.023418442023093185, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.026020491136770206, 0.4375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.026020491136770206, 0.5375, 'musicas_unicas_semana <= 110.5\ngini = 0.5\nsamples = 12\nvalue = [6, 6]\nclass = 0'),
#  Text(0.024719466579931695, 0.5125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(0.027321515693608717, 0.5125, 'log_notificacoes <= 4.35\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = 0'),
#  Text(0.026020491136770206, 0.4875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.028622540250447227, 0.4875, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0'),
#  Text(0.02536997885835095, 0.5625, 'gini = 0.0\nsamples = 40\nvalue = [40, 0]\nclass = 0'),
#  Text(0.02667100341518946, 0.5875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.029273052528866483, 0.6375, 'horas_semanais <= 8.725\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = 1'),
#  Text(0.027972027972027972, 0.6125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.030574077085704993, 0.6125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.04618637176776712, 0.6875, 'musicas_unicas_semana <= 148.0\ngini = 0.382\nsamples = 70\nvalue = [52, 18]\nclass = 0'),
#  Text(0.03903073670515531, 0.6625, 'taxa_musicas_unicas <= 0.515\ngini = 0.487\nsamples = 31\nvalue = [18, 13]\nclass = 0'),
#  Text(0.03447715075622052, 0.6375, 'taxa_skip_musica <= 0.03\ngini = 0.305\nsamples = 16\nvalue = [13, 3]\nclass = 0'),
#  Text(0.03317612619938201, 0.6125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.03577817531305903, 0.6125, 'notificacoes_clicadas <= 145.0\ngini = 0.231\nsamples = 15\nvalue = [13, 2]\nclass = 0'),
#  Text(0.03447715075622052, 0.5875, 'horas_semanais <= 18.498\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = 0'),
#  Text(0.03317612619938201, 0.5625, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = 0'),
#  Text(0.03577817531305903, 0.5625, 'musicas_unicas_semana <= 120.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.03447715075622052, 0.5375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.03707919986989754, 0.5375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.03707919986989754, 0.5875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.043584322654090096, 0.6375, 'taxa_skip_musica <= 0.055\ngini = 0.444\nsamples = 15\nvalue = [5, 10]\nclass = 1'),
#  Text(0.040982273540413075, 0.6125, 'taxa_musicas_unicas <= 0.516\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = 0'),
#  Text(0.039681248983574564, 0.5875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.042283298097251586, 0.5875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.04618637176776712, 0.6125, 'num_amigos_plataforma <= 95.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]\nclass = 1'),
#  Text(0.04488534721092861, 0.5875, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = 1'),
#  Text(0.04748739632460563, 0.5875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.05334200683037892, 0.6625, 'data_inscricao <= 177.5\ngini = 0.224\nsamples = 39\nvalue = [34, 5]\nclass = 0'),
#  Text(0.05008944543828265, 0.6375, 'num_playlists_compartilhadas <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.04878842088144414, 0.6125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.05139046999512116, 0.6125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.056594568222475196, 0.6375, 'num_playlists_criadas <= 8.5\ngini = 0.153\nsamples = 36\nvalue = [33, 3]\nclass = 0'),
#  Text(0.05399251910879818, 0.6125, 'taxa_musicas_unicas <= 0.517\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = 0'),
#  Text(0.05269149455195967, 0.5875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.05529354366563669, 0.5875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.05919661733615222, 0.6125, 'musicas_tocadas_semana <= 367.5\ngini = 0.062\nsamples = 31\nvalue = [30, 1]\nclass = 0'),
#  Text(0.057895592779313707, 0.5875, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]\nclass = 0'),
#  Text(0.06049764189299073, 0.5875, 'num_playlists_criadas <= 11.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.05919661733615222, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.06179866644982924, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.034802406895430155, 0.7125, 'gini = 0.0\nsamples = 48\nvalue = [48, 0]\nclass = 0'),
#  Text(0.03610343145226866, 0.7375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.06570174012034477, 0.7625, 'num_playlists_criadas <= 11.5\ngini = 0.061\nsamples = 192\nvalue = [186, 6]\nclass = 0'),
#  Text(0.06440071556350627, 0.7375, 'taxa_musicas_unicas <= 0.512\ngini = 0.11\nsamples = 103\nvalue = [97, 6]\nclass = 0'),
#  Text(0.06309969100666775, 0.7125, 'gini = 0.0\nsamples = 45\nvalue = [45, 0]\nclass = 0'),
#  Text(0.06570174012034477, 0.7125, 'taxa_musicas_unicas <= 0.513\ngini = 0.185\nsamples = 58\nvalue = [52, 6]\nclass = 0'),
#  Text(0.06440071556350627, 0.6875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.06700276467718329, 0.6875, 'musicas_tocadas_semana <= 367.5\ngini = 0.16\nsamples = 57\nvalue = [52, 5]\nclass = 0'),
#  Text(0.06440071556350627, 0.6625, 'musicas_unicas_semana <= 87.0\ngini = 0.048\nsamples = 41\nvalue = [40, 1]\nclass = 0'),
#  Text(0.06309969100666775, 0.6375, 'horas_semanais <= 11.058\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.06179866644982924, 0.6125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.06440071556350627, 0.6125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.06570174012034477, 0.6375, 'gini = 0.0\nsamples = 38\nvalue = [38, 0]\nclass = 0'),
#  Text(0.06960481379086031, 0.6625, 'horas_semanais <= 27.065\ngini = 0.375\nsamples = 16\nvalue = [12, 4]\nclass = 0'),
#  Text(0.06830378923402179, 0.6375, 'taxa_skip_musica <= 0.075\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = 1'),
#  Text(0.06700276467718329, 0.6125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.06960481379086031, 0.6125, 'taxa_skip_musica <= 0.195\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = 0'),
#  Text(0.06830378923402179, 0.5875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.07090583834769881, 0.5875, 'num_amigos_plataforma <= 69.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.06960481379086031, 0.5625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.07220686290453732, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.07090583834769881, 0.6375, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0'),
#  Text(0.06700276467718329, 0.7375, 'gini = 0.0\nsamples = 89\nvalue = [89, 0]\nclass = 0'),
#  Text(0.2587735977458225, 0.7875, 'taxa_musicas_unicas <= 0.53\ngini = 0.217\nsamples = 3769\nvalue = [3303, 466]\nclass = 0'),
#  Text(0.257472573188984, 0.7625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.260074622302661, 0.7625, 'horas_semanais <= 14.183\ngini = 0.216\nsamples = 3768\nvalue = [3303, 465]\nclass = 0'),
#  Text(0.16199816376392503, 0.7375, 'taxa_musicas_unicas <= 0.864\ngini = 0.194\nsamples = 1778\nvalue = [1585, 193]\nclass = 0'),
#  Text(0.159396114650248, 0.7125, 'musicas_unicas_semana <= 214.5\ngini = 0.192\nsamples = 1775\nvalue = [1584, 191]\nclass = 0'),
#  Text(0.1580950900934095, 0.6875, 'taxa_musicas_unicas <= 0.53\ngini = 0.191\nsamples = 1774\nvalue = [1584, 190]\nclass = 0'),
#  Text(0.156794065536571, 0.6625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.159396114650248, 0.6625, 'data_inscricao <= 572.5\ngini = 0.19\nsamples = 1773\nvalue = [1584, 189]\nclass = 0'),
#  Text(0.08876189217758985, 0.6375, 'data_inscricao <= 559.0\ngini = 0.246\nsamples = 404\nvalue = [346.0, 58.0]\nclass = 0'),
#  Text(0.08143092372743535, 0.6125, 'taxa_musicas_unicas <= 0.538\ngini = 0.233\nsamples = 394\nvalue = [341.0, 53.0]\nclass = 0'),
#  Text(0.07610993657505286, 0.5875, 'tempo_medio_sessao <= 1.226\ngini = 0.486\nsamples = 12\nvalue = [7, 5]\nclass = 0'),
#  Text(0.07480891201821434, 0.5625, 'idade <= 36.0\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = 0'),
#  Text(0.07350788746137583, 0.5375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.07610993657505286, 0.5375, 'taxa_skip_musica <= 0.165\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = 0'),
#  Text(0.07480891201821434, 0.5125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.07741096113189136, 0.5125, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = 0'),
#  Text(0.07741096113189136, 0.5625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.08675191087981786, 0.5875, 'taxa_skip_musica <= 0.005\ngini = 0.22\nsamples = 382\nvalue = [334, 48]\nclass = 0'),
#  Text(0.08001301024556838, 0.5625, 'horas_semanais <= 5.819\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = 0'),
#  Text(0.07871198568872988, 0.5375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.0813140348024069, 0.5375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.09349081151406732, 0.5625, 'musicas_tocadas_semana <= 57.5\ngini = 0.211\nsamples = 375\nvalue = [330, 45]\nclass = 0'),
#  Text(0.08391608391608392, 0.5375, 'taxa_skip_musica <= 0.465\ngini = 0.102\nsamples = 93\nvalue = [88, 5]\nclass = 0'),
#  Text(0.08066352252398765, 0.5125, 'taxa_skip_musica <= 0.015\ngini = 0.045\nsamples = 87\nvalue = [85, 2]\nclass = 0'),
#  Text(0.07806147341031063, 0.4875, 'notificacoes_clicadas <= 60.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.07676044885347211, 0.4625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.07936249796714913, 0.4625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.08326557163766467, 0.4875, 'data_inscricao <= 47.0\ngini = 0.024\nsamples = 84\nvalue = [83, 1]\nclass = 0'),
#  Text(0.08196454708082615, 0.4625, 'notificacoes_clicadas <= 12.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = 0'),
#  Text(0.08066352252398765, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.08326557163766467, 0.4375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.08456659619450317, 0.4625, 'gini = 0.0\nsamples = 78\nvalue = [78, 0]\nclass = 0'),
#  Text(0.08716864530818019, 0.5125, 'num_amigos_plataforma <= 58.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = 0'),
#  Text(0.08586762075134168, 0.4875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.0884696698650187, 0.4875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.10306553911205074, 0.5375, 'horas_semanais <= 3.112\ngini = 0.243\nsamples = 282\nvalue = [242, 40]\nclass = 0'),
#  Text(0.10176451455521222, 0.5125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.10436656366888925, 0.5125, 'taxa_musicas_unicas <= 0.69\ngini = 0.239\nsamples = 281\nvalue = [242, 39]\nclass = 0'),
#  Text(0.0919661733615222, 0.4875, 'musicas_tocadas_semana <= 58.5\ngini = 0.181\nsamples = 169\nvalue = [152, 17]\nclass = 0'),
#  Text(0.09066514880468368, 0.4625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.0932671979183607, 0.4625, 'tempo_medio_sessao <= 0.597\ngini = 0.172\nsamples = 168\nvalue = [152, 16]\nclass = 0'),
#  Text(0.08586762075134168, 0.4375, 'tempo_medio_sessao <= 0.537\ngini = 0.295\nsamples = 39\nvalue = [32, 7]\nclass = 0'),
#  Text(0.08326557163766467, 0.4125, 'musicas_unicas_semana <= 58.0\ngini = 0.239\nsamples = 36\nvalue = [31, 5]\nclass = 0'),
#  Text(0.08196454708082615, 0.3875, 'musicas_tocadas_semana <= 100.5\ngini = 0.444\nsamples = 15\nvalue = [10, 5]\nclass = 0'),
#  Text(0.08066352252398765, 0.3625, 'num_amigos_plataforma <= 46.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]\nclass = 0'),
#  Text(0.07936249796714913, 0.3375, 'num_amigos_plataforma <= 40.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = 0'),
#  Text(0.07806147341031063, 0.3125, 'idade <= 85.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.07676044885347211, 0.2875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.07936249796714913, 0.2875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.08066352252398765, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.08196454708082615, 0.3375, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = 0'),
#  Text(0.08326557163766467, 0.3625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.08456659619450317, 0.3875, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]\nclass = 0'),
#  Text(0.0884696698650187, 0.4125, 'taxa_skip_musica <= 0.415\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.08716864530818019, 0.3875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.08977069442185721, 0.3875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.10066677508537973, 0.4375, 'musicas_tocadas_semana <= 263.5\ngini = 0.13\nsamples = 129\nvalue = [120, 9]\nclass = 0'),
#  Text(0.09660107334525939, 0.4125, 'taxa_skip_musica <= 0.455\ngini = 0.118\nsamples = 127\nvalue = [119, 8]\nclass = 0'),
#  Text(0.09237274353553424, 0.3875, 'tempo_medio_sessao <= 1.431\ngini = 0.095\nsamples = 120\nvalue = [114, 6]\nclass = 0'),
#  Text(0.08781915758659944, 0.3625, 'num_artistas_favoritos <= 6.5\ngini = 0.026\nsamples = 75\nvalue = [74, 1]\nclass = 0'),
#  Text(0.08651813302976094, 0.3375, 'gini = 0.0\nsamples = 54\nvalue = [54, 0]\nclass = 0'),
#  Text(0.08912018214343796, 0.3375, 'idade <= 33.5\ngini = 0.091\nsamples = 21\nvalue = [20, 1]\nclass = 0'),
#  Text(0.08781915758659944, 0.3125, 'log_notificacoes <= 3.598\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = 0'),
#  Text(0.08651813302976094, 0.2875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.08912018214343796, 0.2875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.09042120670027647, 0.3125, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = 0'),
#  Text(0.09692632948446903, 0.3625, 'idade <= 22.5\ngini = 0.198\nsamples = 45\nvalue = [40, 5]\nclass = 0'),
#  Text(0.094324280370792, 0.3375, 'idade <= 20.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.09302325581395349, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.09562530492763051, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.09952837859814603, 0.3375, 'tempo_medio_sessao <= 1.455\ngini = 0.133\nsamples = 42\nvalue = [39, 3]\nclass = 0'),
#  Text(0.09822735404130753, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.10082940315498455, 0.3125, 'data_inscricao <= 523.5\ngini = 0.093\nsamples = 41\nvalue = [39, 2]\nclass = 0'),
#  Text(0.09952837859814603, 0.2875, 'taxa_skip_musica <= 0.395\ngini = 0.049\nsamples = 40\nvalue = [39, 1]\nclass = 0'),
#  Text(0.09822735404130753, 0.2625, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]\nclass = 0'),
#  Text(0.10082940315498455, 0.2625, 'num_playlists_compartilhadas <= 4.0\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = 0'),
#  Text(0.09952837859814603, 0.2375, 'notificacoes_clicadas <= 29.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.09822735404130753, 0.2125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.10082940315498455, 0.2125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.10213042771182305, 0.2375, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0'),
#  Text(0.10213042771182305, 0.2875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.10082940315498455, 0.3875, 'taxa_musicas_unicas <= 0.569\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = 0'),
#  Text(0.09952837859814603, 0.3625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.10213042771182305, 0.3625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.10473247682550008, 0.4125, 'num_playlists_criadas <= 9.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.10343145226866157, 0.3875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.1060335013823386, 0.3875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.1167669539762563, 0.4875, 'taxa_musicas_unicas <= 0.714\ngini = 0.316\nsamples = 112\nvalue = [90, 22]\nclass = 0'),
#  Text(0.11253862416653114, 0.4625, 'tempo_medio_sessao <= 1.049\ngini = 0.483\nsamples = 22\nvalue = [13, 9]\nclass = 0'),
#  Text(0.11123759960969264, 0.4375, 'num_playlists_compartilhadas <= 3.5\ngini = 0.426\nsamples = 13\nvalue = [4, 9]\nclass = 1'),
#  Text(0.10993657505285412, 0.4125, 'taxa_musicas_unicas <= 0.705\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = 0'),
#  Text(0.10863555049601561, 0.3875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.11123759960969264, 0.3875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.11253862416653114, 0.4125, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = 1'),
#  Text(0.11383964872336966, 0.4375, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0'),
#  Text(0.12099528378598146, 0.4625, 'horas_semanais <= 13.763\ngini = 0.247\nsamples = 90\nvalue = [77.0, 13.0]\nclass = 0'),
#  Text(0.11839323467230443, 0.4375, 'taxa_musicas_unicas <= 0.828\ngini = 0.212\nsamples = 83\nvalue = [73, 10]\nclass = 0'),
#  Text(0.11709221011546593, 0.4125, 'taxa_musicas_unicas <= 0.771\ngini = 0.282\nsamples = 59\nvalue = [49, 10]\nclass = 0'),
#  Text(0.11383964872336966, 0.3875, 'num_amigos_plataforma <= 89.0\ngini = 0.105\nsamples = 36\nvalue = [34, 2]\nclass = 0'),
#  Text(0.11253862416653114, 0.3625, 'num_amigos_plataforma <= 19.5\ngini = 0.056\nsamples = 35\nvalue = [34, 1]\nclass = 0'),
#  Text(0.11123759960969264, 0.3375, 'data_inscricao <= 378.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.10993657505285412, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.11253862416653114, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.11383964872336966, 0.3375, 'gini = 0.0\nsamples = 33\nvalue = [33, 0]\nclass = 0'),
#  Text(0.11514067328020816, 0.3625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.1203447715075622, 0.3875, 'tempo_medio_sessao <= 1.332\ngini = 0.454\nsamples = 23\nvalue = [15, 8]\nclass = 0'),
#  Text(0.11774272239388518, 0.3625, 'tempo_medio_sessao <= 0.461\ngini = 0.305\nsamples = 16\nvalue = [13, 3]\nclass = 0'),
#  Text(0.11644169783704668, 0.3375, 'musicas_unicas_semana <= 100.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = 1'),
#  Text(0.11514067328020816, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.11774272239388518, 0.3125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.1190437469507237, 0.3375, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = 0'),
#  Text(0.12294682062123923, 0.3625, 'horas_semanais <= 8.05\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = 1'),
#  Text(0.12164579606440072, 0.3375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(0.12424784517807774, 0.3375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.11969425922914295, 0.4125, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]\nclass = 0'),
#  Text(0.12359733289965848, 0.4375, 'musicas_tocadas_semana <= 216.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = 0'),
#  Text(0.12229630834281997, 0.4125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.124898357456497, 0.4125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.09609286062774434, 0.6125, 'log_notificacoes <= 3.726\ngini = 0.5\nsamples = 10\nvalue = [5, 5]\nclass = 0'),
#  Text(0.09479183607090584, 0.5875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(0.09739388518458286, 0.5875, 'num_playlists_compartilhadas <= 3.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = 0'),
#  Text(0.09609286062774434, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.09869490974142137, 0.5625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.23003033712290616, 0.6375, 'horas_semanais <= 12.411\ngini = 0.173\nsamples = 1369\nvalue = [1238, 131]\nclass = 0'),
#  Text(0.19587137517279232, 0.6125, 'horas_semanais <= 12.392\ngini = 0.185\nsamples = 1193\nvalue = [1070, 123]\nclass = 0'),
#  Text(0.19457035061595382, 0.5875, 'musicas_unicas_semana <= 190.5\ngini = 0.184\nsamples = 1192\nvalue = [1070, 122]\nclass = 0'),
#  Text(0.19326932605911532, 0.5625, 'idade <= 28.5\ngini = 0.183\nsamples = 1191\nvalue = [1070, 121]\nclass = 0'),
#  Text(0.14709708895755408, 0.5375, 'tempo_medio_sessao <= 0.802\ngini = 0.246\nsamples = 216\nvalue = [185, 31]\nclass = 0'),
#  Text(0.13855911530330134, 0.5125, 'musicas_unicas_semana <= 87.5\ngini = 0.361\nsamples = 89\nvalue = [68, 21]\nclass = 0'),
#  Text(0.13725809074646284, 0.4875, 'tempo_medio_sessao <= 0.766\ngini = 0.417\nsamples = 71\nvalue = [50, 21]\nclass = 0'),
#  Text(0.13595706618962433, 0.4625, 'taxa_musicas_unicas <= 0.794\ngini = 0.379\nsamples = 67\nvalue = [50, 17]\nclass = 0'),
#  Text(0.1320539925191088, 0.4375, 'horas_semanais <= 6.036\ngini = 0.311\nsamples = 57\nvalue = [46, 11]\nclass = 0'),
#  Text(0.12815091884859325, 0.4125, 'taxa_musicas_unicas <= 0.532\ngini = 0.227\nsamples = 46\nvalue = [40, 6]\nclass = 0'),
#  Text(0.12684989429175475, 0.3875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.12945194340543179, 0.3875, 'musicas_tocadas_semana <= 45.0\ngini = 0.198\nsamples = 45\nvalue = [40, 5]\nclass = 0'),
#  Text(0.12815091884859325, 0.3625, 'musicas_unicas_semana <= 14.5\ngini = 0.33\nsamples = 24\nvalue = [19, 5]\nclass = 0'),
#  Text(0.12684989429175475, 0.3375, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = 0'),
#  Text(0.12945194340543179, 0.3375, 'musicas_tocadas_semana <= 29.5\ngini = 0.473\nsamples = 13\nvalue = [8, 5]\nclass = 0'),
#  Text(0.12815091884859325, 0.3125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.1307529679622703, 0.3125, 'musicas_unicas_semana <= 27.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = 0'),
#  Text(0.12945194340543179, 0.2875, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = 0'),
#  Text(0.1320539925191088, 0.2875, 'log_notificacoes <= 4.162\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.1307529679622703, 0.2625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.1333550170759473, 0.2625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.1307529679622703, 0.3625, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]\nclass = 0'),
#  Text(0.13595706618962433, 0.4125, 'data_inscricao <= 1671.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = 0'),
#  Text(0.13465604163278583, 0.3875, 'num_pausas_assinatura <= 1.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = 0'),
#  Text(0.1333550170759473, 0.3625, 'tempo_medio_sessao <= 0.582\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.1320539925191088, 0.3375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.13465604163278583, 0.3375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.13595706618962433, 0.3625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.13725809074646284, 0.3875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.13986013986013987, 0.4375, 'idade <= 22.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]\nclass = 1'),
#  Text(0.13855911530330134, 0.4125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.14116116441697837, 0.4125, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = 1'),
#  Text(0.13855911530330134, 0.4625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(0.13986013986013987, 0.4875, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = 0'),
#  Text(0.1556350626118068, 0.5125, 'tempo_medio_sessao <= 2.217\ngini = 0.145\nsamples = 127\nvalue = [117, 10]\nclass = 0'),
#  Text(0.1543340380549683, 0.4875, 'musicas_unicas_semana <= 163.5\ngini = 0.133\nsamples = 126\nvalue = [117, 9]\nclass = 0'),
#  Text(0.15303301349812978, 0.4625, 'data_inscricao <= 2296.0\ngini = 0.12\nsamples = 125\nvalue = [117, 8]\nclass = 0'),
#  Text(0.14799154334038056, 0.4375, 'tempo_medio_sessao <= 2.049\ngini = 0.085\nsamples = 112\nvalue = [107, 5]\nclass = 0'),
#  Text(0.14441372580907463, 0.4125, 'idade <= 27.5\ngini = 0.07\nsamples = 110\nvalue = [106, 4]\nclass = 0'),
#  Text(0.14116116441697837, 0.3875, 'num_playlists_criadas <= 8.5\ngini = 0.056\nsamples = 105\nvalue = [102, 3]\nclass = 0'),
#  Text(0.13855911530330134, 0.3625, 'musicas_unicas_semana <= 55.0\ngini = 0.165\nsamples = 22\nvalue = [20, 2]\nclass = 0'),
#  Text(0.13725809074646284, 0.3375, 'horas_semanais <= 3.504\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = 0'),
#  Text(0.13595706618962433, 0.3125, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.13855911530330134, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.13986013986013987, 0.3375, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = 0'),
#  Text(0.14376321353065538, 0.3625, 'num_playlists_compartilhadas <= 12.5\ngini = 0.024\nsamples = 83\nvalue = [82, 1]\nclass = 0'),
#  Text(0.14246218897381688, 0.3375, 'gini = 0.0\nsamples = 76\nvalue = [76, 0]\nclass = 0'),
#  Text(0.1450642380874939, 0.3375, 'data_inscricao <= 904.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = 0'),
#  Text(0.14376321353065538, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.14636526264433242, 0.3125, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0'),
#  Text(0.14766628720117092, 0.3875, 'num_artistas_favoritos <= 7.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = 0'),
#  Text(0.14636526264433242, 0.3625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.14896731175800942, 0.3625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.15156936087168646, 0.4125, 'notificacoes_clicadas <= 66.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.15026833631484796, 0.3875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.15287038542852496, 0.3875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.158074483655879, 0.4375, 'data_inscricao <= 2343.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]\nclass = 0'),
#  Text(0.1567734590990405, 0.4125, 'taxa_musicas_unicas <= 0.562\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = 1'),
#  Text(0.15547243454220197, 0.3875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.158074483655879, 0.3875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.1593755082127175, 0.4125, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0'),
#  Text(0.1556350626118068, 0.4625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.15693608716864532, 0.4875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.23944156316067652, 0.5375, 'num_amigos_plataforma <= 99.5\ngini = 0.168\nsamples = 975\nvalue = [885, 90]\nclass = 0'),
#  Text(0.23814053860383802, 0.5125, 'notificacoes_clicadas <= 270.5\ngini = 0.166\nsamples = 974\nvalue = [885, 89]\nclass = 0'),
#  Text(0.22249997458936413, 0.4875, 'taxa_skip_musica <= 0.415\ngini = 0.162\nsamples = 959\nvalue = [874, 85]\nclass = 0'),
#  Text(0.1990249939014474, 0.4625, 'musicas_tocadas_semana <= 177.5\ngini = 0.149\nsamples = 841\nvalue = [773, 68]\nclass = 0'),
#  Text(0.17842077980159377, 0.4375, 'musicas_unicas_semana <= 7.5\ngini = 0.137\nsamples = 771\nvalue = [714, 57]\nclass = 0'),
#  Text(0.16327858188323305, 0.4125, 'horas_semanais <= 0.799\ngini = 0.295\nsamples = 39\nvalue = [32, 7]\nclass = 0'),
#  Text(0.160676532769556, 0.3875, 'taxa_skip_musica <= 0.045\ngini = 0.208\nsamples = 34\nvalue = [30, 4]\nclass = 0'),
#  Text(0.1593755082127175, 0.3625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.16197755732639454, 0.3625, 'data_inscricao <= 2460.5\ngini = 0.165\nsamples = 33\nvalue = [30, 3]\nclass = 0'),
#  Text(0.160676532769556, 0.3375, 'taxa_musicas_unicas <= 0.829\ngini = 0.117\nsamples = 32\nvalue = [30, 2]\nclass = 0'),
#  Text(0.1593755082127175, 0.3125, 'horas_semanais <= 0.298\ngini = 0.062\nsamples = 31\nvalue = [30, 1]\nclass = 0'),
#  Text(0.158074483655879, 0.2875, 'taxa_skip_musica <= 0.22\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.1567734590990405, 0.2625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.1593755082127175, 0.2625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.160676532769556, 0.2875, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]\nclass = 0'),
#  Text(0.16197755732639454, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.16327858188323305, 0.3375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.16588063099691006, 0.3875, 'num_playlists_criadas <= 12.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = 1'),
#  Text(0.16457960644007155, 0.3625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.1671816555537486, 0.3625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.19356297771995445, 0.4125, 'horas_semanais <= 9.246\ngini = 0.127\nsamples = 732\nvalue = [682.0, 50.0]\nclass = 0'),
#  Text(0.18343429825987967, 0.3875, 'musicas_tocadas_semana <= 138.5\ngini = 0.147\nsamples = 577\nvalue = [531.0, 46.0]\nclass = 0'),
#  Text(0.1768376971865344, 0.3625, 'horas_semanais <= 9.224\ngini = 0.128\nsamples = 538\nvalue = [501.0, 37.0]\nclass = 0'),
#  Text(0.17553667262969588, 0.3375, 'horas_semanais <= 6.596\ngini = 0.125\nsamples = 537\nvalue = [501, 36]\nclass = 0'),
#  Text(0.16884859326719792, 0.3125, 'horas_semanais <= 6.582\ngini = 0.149\nsamples = 408\nvalue = [375, 33]\nclass = 0'),
#  Text(0.16754756871035942, 0.2875, 'tempo_medio_sessao <= 1.346\ngini = 0.141\nsamples = 406\nvalue = [375, 31]\nclass = 0'),
#  Text(0.16197755732639454, 0.2625, 'taxa_musicas_unicas <= 0.766\ngini = 0.129\nsamples = 391\nvalue = [364.0, 27.0]\nclass = 0'),
#  Text(0.1547406082289803, 0.2375, 'taxa_musicas_unicas <= 0.764\ngini = 0.151\nsamples = 317\nvalue = [291, 26]\nclass = 0'),
#  Text(0.1534395836721418, 0.2125, 'taxa_musicas_unicas <= 0.681\ngini = 0.146\nsamples = 316\nvalue = [291, 25]\nclass = 0'),
#  Text(0.1402667100341519, 0.1875, 'data_inscricao <= 827.5\ngini = 0.11\nsamples = 239\nvalue = [225, 14]\nclass = 0'),
#  Text(0.13246056269312084, 0.1625, 'taxa_skip_musica <= 0.135\ngini = 0.251\nsamples = 34\nvalue = [29, 5]\nclass = 0'),
#  Text(0.1298585135794438, 0.1375, 'horas_semanais <= 4.135\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = 1'),
#  Text(0.1285574890226053, 0.1125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.1311595381362823, 0.1125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.13506261180679785, 0.1375, 'data_inscricao <= 819.0\ngini = 0.124\nsamples = 30\nvalue = [28, 2]\nclass = 0'),
#  Text(0.13376158724995935, 0.1125, 'notificacoes_clicadas <= 0.5\ngini = 0.067\nsamples = 29\nvalue = [28, 1]\nclass = 0'),
#  Text(0.13246056269312084, 0.0875, 'horas_semanais <= 5.639\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.1311595381362823, 0.0625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.13376158724995935, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.13506261180679785, 0.0875, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]\nclass = 0'),
#  Text(0.13636363636363635, 0.1125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.14807285737518297, 0.1625, 'num_amigos_plataforma <= 37.5\ngini = 0.084\nsamples = 205\nvalue = [196, 9]\nclass = 0'),
#  Text(0.1415677345909904, 0.1375, 'num_artistas_favoritos <= 1.5\ngini = 0.219\nsamples = 32\nvalue = [28, 4]\nclass = 0'),
#  Text(0.1389656854773134, 0.1125, 'taxa_musicas_unicas <= 0.636\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.13766466092047489, 0.0875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.1402667100341519, 0.0875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.14416978370466743, 0.1125, 'log_notificacoes <= 4.832\ngini = 0.128\nsamples = 29\nvalue = [27, 2]\nclass = 0'),
#  Text(0.14286875914782893, 0.0875, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]\nclass = 0'),
#  Text(0.14547080826150594, 0.0875, 'horas_semanais <= 3.882\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = 0'),
#  Text(0.14416978370466743, 0.0625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.14677183281834444, 0.0625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.15457798015937552, 0.1375, 'musicas_tocadas_semana <= 99.5\ngini = 0.056\nsamples = 173\nvalue = [168, 5]\nclass = 0'),
#  Text(0.15197593104569848, 0.1125, 'tempo_medio_sessao <= 0.513\ngini = 0.037\nsamples = 159\nvalue = [156, 3]\nclass = 0'),
#  Text(0.15067490648885998, 0.0875, 'tempo_medio_sessao <= 0.499\ngini = 0.082\nsamples = 70\nvalue = [67, 3]\nclass = 0'),
#  Text(0.14937388193202147, 0.0625, 'num_amigos_plataforma <= 89.5\ngini = 0.029\nsamples = 68\nvalue = [67, 1]\nclass = 0'),
#  Text(0.14807285737518297, 0.0375, 'gini = 0.0\nsamples = 64\nvalue = [64, 0]\nclass = 0'),
#  Text(0.15067490648885998, 0.0375, 'musicas_unicas_semana <= 20.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.14937388193202147, 0.0125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.15197593104569848, 0.0125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.15197593104569848, 0.0625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.15327695560253699, 0.0875, 'gini = 0.0\nsamples = 89\nvalue = [89, 0]\nclass = 0'),
#  Text(0.15718002927305252, 0.1125, 'data_inscricao <= 2218.0\ngini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = 0'),
#  Text(0.15587900471621402, 0.0875, 'horas_semanais <= 5.136\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = 0'),
#  Text(0.15457798015937552, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.15718002927305252, 0.0625, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = 0'),
#  Text(0.15848105382989103, 0.0875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.16661245731013172, 0.1875, 'taxa_musicas_unicas <= 0.685\ngini = 0.245\nsamples = 77\nvalue = [66, 11]\nclass = 0'),
#  Text(0.1640104081964547, 0.1625, 'data_inscricao <= 1083.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.1627093836396162, 0.1375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.1653114327532932, 0.1375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.16921450642380875, 0.1625, 'num_playlists_criadas <= 3.5\ngini = 0.214\nsamples = 74\nvalue = [65, 9]\nclass = 0'),
#  Text(0.16791348186697025, 0.1375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.17051553098064726, 0.1375, 'num_playlists_criadas <= 15.0\ngini = 0.195\nsamples = 73\nvalue = [65, 8]\nclass = 0'),
#  Text(0.16563668889250285, 0.1125, 'data_inscricao <= 2135.0\ngini = 0.146\nsamples = 63\nvalue = [58, 5]\nclass = 0'),
#  Text(0.16238412750040657, 0.0875, 'taxa_musicas_unicas <= 0.689\ngini = 0.077\nsamples = 50\nvalue = [48, 2]\nclass = 0'),
#  Text(0.15978207838672956, 0.0625, 'idade <= 56.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.15848105382989103, 0.0375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.16108310294356806, 0.0375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.1649861766140836, 0.0625, 'num_amigos_plataforma <= 29.0\ngini = 0.042\nsamples = 47\nvalue = [46, 1]\nclass = 0'),
#  Text(0.16368515205724507, 0.0375, 'num_artistas_favoritos <= 3.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.16238412750040657, 0.0125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.1649861766140836, 0.0125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.1662872011709221, 0.0375, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]\nclass = 0'),
#  Text(0.1688892502845991, 0.0875, 'data_inscricao <= 2202.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]\nclass = 0'),
#  Text(0.1675882257277606, 0.0625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.17019027484143764, 0.0625, 'taxa_musicas_unicas <= 0.738\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = 0'),
#  Text(0.1688892502845991, 0.0375, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = 0'),
#  Text(0.17149129939827615, 0.0375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.1753943730687917, 0.1125, 'idade <= 58.0\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = 0'),
#  Text(0.17409334851195316, 0.0875, 'data_inscricao <= 995.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = 1'),
#  Text(0.17279232395511465, 0.0625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.1753943730687917, 0.0625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.1766953976256302, 0.0875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.15604163278581884, 0.2125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.16921450642380875, 0.2375, 'taxa_musicas_unicas <= 0.848\ngini = 0.027\nsamples = 74\nvalue = [73, 1]\nclass = 0'),
#  Text(0.16791348186697025, 0.2125, 'gini = 0.0\nsamples = 68\nvalue = [68, 0]\nclass = 0'),
#  Text(0.17051553098064726, 0.2125, 'idade <= 42.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = 0'),
#  Text(0.16921450642380875, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.17181655553748576, 0.1875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.1731175800943243, 0.2625, 'tempo_medio_sessao <= 1.364\ngini = 0.391\nsamples = 15\nvalue = [11, 4]\nclass = 0'),
#  Text(0.17181655553748576, 0.2375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.1744186046511628, 0.2375, 'taxa_musicas_unicas <= 0.753\ngini = 0.26\nsamples = 13\nvalue = [11, 2]\nclass = 0'),
#  Text(0.1731175800943243, 0.2125, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = 0'),
#  Text(0.1757196292080013, 0.2125, 'musicas_tocadas_semana <= 85.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.1744186046511628, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.1770206537648398, 0.1875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.17014961782403643, 0.2875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.18222475199219385, 0.3125, 'tempo_medio_sessao <= 1.742\ngini = 0.045\nsamples = 129\nvalue = [126, 3]\nclass = 0'),
#  Text(0.17962270287851684, 0.2875, 'idade <= 31.5\ngini = 0.017\nsamples = 117\nvalue = [116, 1]\nclass = 0'),
#  Text(0.17832167832167833, 0.2625, 'tempo_medio_sessao <= 1.222\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.1770206537648398, 0.2375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.17962270287851684, 0.2375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.18092372743535534, 0.2625, 'gini = 0.0\nsamples = 113\nvalue = [113, 0]\nclass = 0'),
#  Text(0.18482680110587088, 0.2875, 'tempo_medio_sessao <= 1.79\ngini = 0.278\nsamples = 12\nvalue = [10, 2]\nclass = 0'),
#  Text(0.18352577654903238, 0.2625, 'clicou_notificacao <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.18222475199219385, 0.2375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.18482680110587088, 0.2375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.18612782566270938, 0.2625, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0'),
#  Text(0.17813872174337292, 0.3375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.19003089933322492, 0.3625, 'taxa_skip_musica <= 0.09\ngini = 0.355\nsamples = 39\nvalue = [30, 9]\nclass = 0'),
#  Text(0.18612782566270938, 0.3375, 'num_playlists_compartilhadas <= 5.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = 1'),
#  Text(0.18482680110587088, 0.3125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(0.1874288502195479, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.19393397300374043, 0.3375, 'num_playlists_criadas <= 6.5\ngini = 0.251\nsamples = 34\nvalue = [29, 5]\nclass = 0'),
#  Text(0.19003089933322492, 0.3125, 'num_amigos_plataforma <= 32.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = 1'),
#  Text(0.1887298747763864, 0.2875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.19133192389006343, 0.2875, 'taxa_skip_musica <= 0.35\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.19003089933322492, 0.2625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.19263294844690193, 0.2625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.19783704667425597, 0.3125, 'idade <= 79.5\ngini = 0.128\nsamples = 29\nvalue = [27, 2]\nclass = 0'),
#  Text(0.19653602211741747, 0.2875, 'num_playlists_criadas <= 19.5\ngini = 0.069\nsamples = 28\nvalue = [27, 1]\nclass = 0'),
#  Text(0.19523499756057897, 0.2625, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]\nclass = 0'),
#  Text(0.19783704667425597, 0.2625, 'idade <= 59.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.19653602211741747, 0.2375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.19913807123109448, 0.2375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.19913807123109448, 0.2875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.20369165718002927, 0.3875, 'data_inscricao <= 600.5\ngini = 0.05\nsamples = 155\nvalue = [151, 4]\nclass = 0'),
#  Text(0.200439095787933, 0.3625, 'data_inscricao <= 588.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.19913807123109448, 0.3375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.2017401203447715, 0.3375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.20694421857212555, 0.3625, 'num_playlists_compartilhadas <= 13.5\ngini = 0.038\nsamples = 153\nvalue = [150, 3]\nclass = 0'),
#  Text(0.20434216945844852, 0.3375, 'taxa_skip_musica <= 0.015\ngini = 0.015\nsamples = 134\nvalue = [133, 1]\nclass = 0'),
#  Text(0.20304114490161002, 0.3125, 'num_amigos_plataforma <= 49.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = 0'),
#  Text(0.2017401203447715, 0.2875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
# ...
#  Text(0.4111237599609693, 0.1125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.4137258090746463, 0.1125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.4143763213530655, 0.2625, 'musicas_tocadas_semana <= 429.0\ngini = 0.401\nsamples = 18\nvalue = [13, 5]\nclass = 0'),
#  Text(0.413075296796227, 0.2375, 'data_inscricao <= 337.0\ngini = 0.231\nsamples = 15\nvalue = [13, 2]\nclass = 0'),
#  Text(0.4117742722393885, 0.2125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.4143763213530655, 0.2125, 'horas_semanais <= 19.715\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = 0'),
#  Text(0.413075296796227, 0.1875, 'num_playlists_compartilhadas <= 9.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.4117742722393885, 0.1625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.4143763213530655, 0.1625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.4156773459099041, 0.1875, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = 0'),
#  Text(0.4156773459099041, 0.2375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.40884696698650186, 0.2875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.41144901610017887, 0.3375, 'musicas_tocadas_semana <= 434.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.41014799154334036, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.4127500406570174, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.3879086030248821, 0.4375, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]\nclass = 0'),
#  Text(0.4267360546430314, 0.4625, 'num_amigos_plataforma <= 58.5\ngini = 0.352\nsamples = 79\nvalue = [61, 18]\nclass = 0'),
#  Text(0.4212067002764677, 0.4375, 'musicas_tocadas_semana <= 566.5\ngini = 0.267\nsamples = 63\nvalue = [53, 10]\nclass = 0'),
#  Text(0.4199056757196292, 0.4125, 'taxa_skip_musica <= 0.1\ngini = 0.248\nsamples = 62\nvalue = [53, 9]\nclass = 0'),
#  Text(0.41665311432753294, 0.3875, 'tempo_medio_sessao <= 2.955\ngini = 0.444\nsamples = 15\nvalue = [10, 5]\nclass = 0'),
#  Text(0.41535208977069443, 0.3625, 'horas_semanais <= 16.804\ngini = 0.5\nsamples = 10\nvalue = [5, 5]\nclass = 0'),
#  Text(0.41405106521385593, 0.3375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.41665311432753294, 0.3375, 'num_playlists_compartilhadas <= 4.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = 1'),
#  Text(0.41535208977069443, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.41795413888437144, 0.3125, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(0.41795413888437144, 0.3625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.4231582371117255, 0.3875, 'taxa_musicas_unicas <= 0.715\ngini = 0.156\nsamples = 47\nvalue = [43, 4]\nclass = 0'),
#  Text(0.42055618799804845, 0.3625, 'num_playlists_compartilhadas <= 16.5\ngini = 0.049\nsamples = 40\nvalue = [39, 1]\nclass = 0'),
#  Text(0.41925516344120994, 0.3375, 'gini = 0.0\nsamples = 37\nvalue = [37, 0]\nclass = 0'),
#  Text(0.42185721255488695, 0.3375, 'horas_semanais <= 24.949\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.42055618799804845, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.4231582371117255, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.4257602862254025, 0.3625, 'taxa_skip_musica <= 0.2\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = 0'),
#  Text(0.424459261668564, 0.3375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.427061310782241, 0.3375, 'taxa_musicas_unicas <= 0.742\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = 1'),
#  Text(0.4257602862254025, 0.3125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.4283623353390795, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.42250772483330623, 0.4125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.43226540900959504, 0.4375, 'taxa_musicas_unicas <= 0.656\ngini = 0.5\nsamples = 16\nvalue = [8, 8]\nclass = 0'),
#  Text(0.43096438445275653, 0.4125, 'taxa_skip_musica <= 0.28\ngini = 0.444\nsamples = 12\nvalue = [4, 8]\nclass = 1'),
#  Text(0.42966335989591803, 0.3875, 'musicas_tocadas_semana <= 238.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = 0'),
#  Text(0.4283623353390795, 0.3625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.43096438445275653, 0.3625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.43226540900959504, 0.3875, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = 1'),
#  Text(0.43356643356643354, 0.4125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.41057489022605304, 0.5125, 'notificacoes_clicadas <= 32.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = 0'),
#  Text(0.40927386566921453, 0.4875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.41187591478289154, 0.4875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.3971326638477801, 0.5375, 'gini = 0.0\nsamples = 48\nvalue = [48, 0]\nclass = 0'),
#  Text(0.4418604651162791, 0.5625, 'horas_semanais <= 14.579\ngini = 0.302\nsamples = 200\nvalue = [163, 37]\nclass = 0'),
#  Text(0.4405594405594406, 0.5375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.4431614896731176, 0.5375, 'num_amigos_plataforma <= 27.5\ngini = 0.286\nsamples = 197\nvalue = [163, 34]\nclass = 0'),
#  Text(0.4348674581232721, 0.5125, 'taxa_skip_musica <= 0.265\ngini = 0.494\nsamples = 9\nvalue = [4, 5]\nclass = 1'),
#  Text(0.43356643356643354, 0.4875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(0.4361684826801106, 0.4875, 'num_amigos_plataforma <= 26.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = 0'),
#  Text(0.4348674581232721, 0.4625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.4374695072369491, 0.4625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.45145552122296306, 0.5125, 'taxa_musicas_unicas <= 0.79\ngini = 0.261\nsamples = 188\nvalue = [159, 29]\nclass = 0'),
#  Text(0.4433241177427224, 0.4875, 'tempo_medio_sessao <= 2.443\ngini = 0.389\nsamples = 53\nvalue = [39, 14]\nclass = 0'),
#  Text(0.4400715563506261, 0.4625, 'data_inscricao <= 732.5\ngini = 0.283\nsamples = 41\nvalue = [34.0, 7.0]\nclass = 0'),
#  Text(0.4374695072369491, 0.4375, 'taxa_skip_musica <= 0.385\ngini = 0.432\nsamples = 19\nvalue = [13, 6]\nclass = 0'),
#  Text(0.4361684826801106, 0.4125, 'horas_semanais <= 25.422\ngini = 0.36\nsamples = 17\nvalue = [13, 4]\nclass = 0'),
#  Text(0.4348674581232721, 0.3875, 'data_inscricao <= 229.0\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = 0'),
#  Text(0.43356643356643354, 0.3625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.4361684826801106, 0.3625, 'data_inscricao <= 435.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = 1'),
#  Text(0.4348674581232721, 0.3375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.4374695072369491, 0.3375, 'num_pausas_assinatura <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.4361684826801106, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.4387705317937876, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.4374695072369491, 0.3875, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = 0'),
#  Text(0.4387705317937876, 0.4125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.4426736054643031, 0.4375, 'horas_semanais <= 15.798\ngini = 0.087\nsamples = 22\nvalue = [21, 1]\nclass = 0'),
#  Text(0.4413725809074646, 0.4125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.4439746300211416, 0.4125, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]\nclass = 0'),
#  Text(0.4465766791348187, 0.4625, 'idade <= 35.5\ngini = 0.486\nsamples = 12\nvalue = [5, 7]\nclass = 1'),
#  Text(0.4452756545779802, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.4478777036916572, 0.4375, 'taxa_musicas_unicas <= 0.773\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = 1'),
#  Text(0.4465766791348187, 0.4125, 'taxa_skip_musica <= 0.04\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.4452756545779802, 0.3875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.4478777036916572, 0.3875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.4491787282484957, 0.4125, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = 1'),
#  Text(0.4595869247032038, 0.4875, 'horas_semanais <= 27.947\ngini = 0.198\nsamples = 135\nvalue = [120, 15]\nclass = 0'),
#  Text(0.45568385103268827, 0.4625, 'num_playlists_criadas <= 14.5\ngini = 0.134\nsamples = 111\nvalue = [103, 8]\nclass = 0'),
#  Text(0.4543828264758497, 0.4375, 'musicas_tocadas_semana <= 436.5\ngini = 0.184\nsamples = 78\nvalue = [70, 8]\nclass = 0'),
#  Text(0.4517807773621727, 0.4125, 'musicas_unicas_semana <= 274.0\ngini = 0.151\nsamples = 73\nvalue = [67, 6]\nclass = 0'),
#  Text(0.4504797528053342, 0.3875, 'musicas_tocadas_semana <= 335.5\ngini = 0.245\nsamples = 42\nvalue = [36, 6]\nclass = 0'),
#  Text(0.4491787282484957, 0.3625, 'taxa_musicas_unicas <= 0.85\ngini = 0.214\nsamples = 41\nvalue = [36, 5]\nclass = 0'),
#  Text(0.4465766791348187, 0.3375, 'horas_semanais <= 14.919\ngini = 0.071\nsamples = 27\nvalue = [26, 1]\nclass = 0'),
#  Text(0.4452756545779802, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.4478777036916572, 0.3125, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]\nclass = 0'),
#  Text(0.4517807773621727, 0.3375, 'taxa_musicas_unicas <= 0.861\ngini = 0.408\nsamples = 14\nvalue = [10, 4]\nclass = 0'),
#  Text(0.4504797528053342, 0.3125, 'data_inscricao <= 825.0\ngini = 0.494\nsamples = 9\nvalue = [5, 4]\nclass = 0'),
#  Text(0.4491787282484957, 0.2875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.4517807773621727, 0.2875, 'taxa_musicas_unicas <= 0.857\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = 0'),
#  Text(0.4504797528053342, 0.2625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.4530818019190112, 0.2625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.4530818019190112, 0.3125, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.4517807773621727, 0.3625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.4530818019190112, 0.3875, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]\nclass = 0'),
#  Text(0.4569848755895268, 0.4125, 'num_artistas_favoritos <= 7.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = 0'),
#  Text(0.45568385103268827, 0.3875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.4582859001463653, 0.3875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.4569848755895268, 0.4375, 'gini = 0.0\nsamples = 33\nvalue = [33, 0]\nclass = 0'),
#  Text(0.4634899983737193, 0.4625, 'horas_semanais <= 29.568\ngini = 0.413\nsamples = 24\nvalue = [17, 7]\nclass = 0'),
#  Text(0.4608879492600423, 0.4375, 'musicas_tocadas_semana <= 497.0\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = 1'),
#  Text(0.4595869247032038, 0.4125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(0.4621889738168808, 0.4125, 'num_amigos_plataforma <= 76.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.4608879492600423, 0.3875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.4634899983737193, 0.3875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.4660920474873963, 0.4375, 'musicas_unicas_semana <= 313.0\ngini = 0.219\nsamples = 16\nvalue = [14, 2]\nclass = 0'),
#  Text(0.4647910229305578, 0.4125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.46739307204423486, 0.4125, 'num_playlists_compartilhadas <= 2.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]\nclass = 0'),
#  Text(0.4660920474873963, 0.3875, 'notificacoes_clicadas <= 1.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.4647910229305578, 0.3625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.46739307204423486, 0.3625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.46869409660107336, 0.3875, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = 0'),
#  Text(0.52297121483168, 0.6625, 'tempo_medio_sessao <= 3.651\ngini = 0.274\nsamples = 482\nvalue = [403, 79]\nclass = 0'),
#  Text(0.5086192876890552, 0.6375, 'taxa_musicas_unicas <= 0.698\ngini = 0.267\nsamples = 478\nvalue = [402, 76]\nclass = 0'),
#  Text(0.483818507074321, 0.6125, 'taxa_skip_musica <= 0.075\ngini = 0.317\nsamples = 309\nvalue = [248.0, 61.0]\nclass = 0'),
#  Text(0.46869409660107336, 0.5875, 'num_amigos_plataforma <= 49.5\ngini = 0.448\nsamples = 56\nvalue = [37, 19]\nclass = 0'),
#  Text(0.4634899983737193, 0.5625, 'num_playlists_criadas <= 12.5\ngini = 0.444\nsamples = 15\nvalue = [5, 10]\nclass = 1'),
#  Text(0.4621889738168808, 0.5375, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = 1'),
#  Text(0.4647910229305578, 0.5375, 'musicas_unicas_semana <= 221.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = 0'),
#  Text(0.4634899983737193, 0.5125, 'idade <= 82.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = 1'),
#  Text(0.4621889738168808, 0.4875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.4647910229305578, 0.4875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.4660920474873963, 0.5125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.4738981948284274, 0.5625, 'data_inscricao <= 2446.0\ngini = 0.343\nsamples = 41\nvalue = [32, 9]\nclass = 0'),
#  Text(0.4725971702715889, 0.5375, 'num_amigos_plataforma <= 69.5\ngini = 0.295\nsamples = 39\nvalue = [32, 7]\nclass = 0'),
#  Text(0.46869409660107336, 0.5125, 'num_artistas_favoritos <= 8.5\ngini = 0.091\nsamples = 21\nvalue = [20, 1]\nclass = 0'),
#  Text(0.46739307204423486, 0.4875, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = 0'),
#  Text(0.46999512115791187, 0.4875, 'data_inscricao <= 2297.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.46869409660107336, 0.4625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.47129614571475037, 0.4625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.4765002439421044, 0.5125, 'tempo_medio_sessao <= 2.028\ngini = 0.444\nsamples = 18\nvalue = [12, 6]\nclass = 0'),
#  Text(0.4751992193852659, 0.4875, 'num_playlists_criadas <= 10.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]\nclass = 1'),
#  Text(0.4738981948284274, 0.4625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(0.4765002439421044, 0.4625, 'musicas_unicas_semana <= 144.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.4751992193852659, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.47780126849894294, 0.4375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.47780126849894294, 0.4875, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0'),
#  Text(0.4751992193852659, 0.5375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.4989429175475687, 0.5875, 'taxa_musicas_unicas <= 0.697\ngini = 0.277\nsamples = 253\nvalue = [211, 42]\nclass = 0'),
#  Text(0.4976418929907302, 0.5625, 'num_artistas_favoritos <= 6.5\ngini = 0.268\nsamples = 251\nvalue = [211, 40]\nclass = 0'),
#  Text(0.48625792811839325, 0.5375, 'taxa_skip_musica <= 0.355\ngini = 0.332\nsamples = 138\nvalue = [109, 29]\nclass = 0'),
#  Text(0.48170434216945845, 0.5125, 'num_playlists_compartilhadas <= 1.5\ngini = 0.269\nsamples = 100\nvalue = [84, 16]\nclass = 0'),
#  Text(0.48040331761261995, 0.4875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.48300536672629696, 0.4875, 'data_inscricao <= 1846.5\ngini = 0.245\nsamples = 98\nvalue = [84, 14]\nclass = 0'),
#  Text(0.48170434216945845, 0.4625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.48430639128313546, 0.4625, 'data_inscricao <= 2468.0\ngini = 0.232\nsamples = 97\nvalue = [84, 13]\nclass = 0'),
#  Text(0.48300536672629696, 0.4375, 'notificacoes_clicadas <= 335.5\ngini = 0.219\nsamples = 96\nvalue = [84, 12]\nclass = 0'),
#  ...]

# %%
# Nível de importância de cada feature avaliada pela árvore de decisão - Variáveis numéricas
feat_import_num = (pd.Series(arvore.feature_importances_,
                                    index=X_train[feat_num].columns)
                                    .sort_values(ascending=False)
                                    .reset_index()
                                    )

feat_import_num['acumulada'] = feat_import_num[0].cumsum()
feat_import_num
# Out:
#                            index         0  acumulada
# 0            taxa_musicas_unicas  0.120664   0.120664
# 1             tempo_medio_sessao  0.111351   0.232014
# 2                 horas_semanais  0.105270   0.337284
# 3                 data_inscricao  0.091871   0.429156
# 4               taxa_skip_musica  0.085897   0.515052
# 5          num_amigos_plataforma  0.081657   0.596710
# 6          musicas_unicas_semana  0.068727   0.665437
# 7         musicas_tocadas_semana  0.066891   0.732328
# 8                          idade  0.053620   0.785948
# 9   num_playlists_compartilhadas  0.046124   0.832072
# 10              log_notificacoes  0.041462   0.873534
# 11         num_playlists_criadas  0.041102   0.914636
# 12         notificacoes_clicadas  0.039223   0.953858
# 13        num_artistas_favoritos  0.030727   0.984585
# 14         num_pausas_assinatura  0.014014   0.998599
# 15            clicou_notificacao  0.001401   1.000000

# %%
# Análise de comportamento por churn com variáveis categóricas
df_analise = X_train[['tipo_assinatura','plano_pagamento','metodo_pagamento','chamados_suporte']].copy()
df_analise[target] = y_train

# Função que cria tabeças cruzadas por variável categórica
def resumo_categorica(var,df=df_analise, target=target):
    tabela = pd.crosstab(df[var], df[target], normalize='columns')

    resumo = tabela.copy()

    resumo['diff_abs'] = resumo[0] - resumo[1]
    resumo['diff_rel'] = resumo[0] / resumo[1]

    return resumo

# %%
resumo_categorica('tipo_assinatura')
# Out:
# churned                 0         1  diff_abs  diff_rel
# tipo_assinatura
# basico           0.276011  0.283315 -0.007304  0.974219
# estudante        0.099861  0.103024 -0.003163  0.969299
# familia premium  0.393233  0.396417 -0.003184  0.991969
# premium          0.230896  0.217245  0.013651  1.062836

# %%
resumo_categorica('plano_pagamento')
# Out:
# churned                 0        1  diff_abs  diff_rel
# plano_pagamento
# anual            0.717019  0.68645  0.030569  1.044532
# mensal           0.282981  0.31355 -0.030569  0.902506

# %%
resumo_categorica('metodo_pagamento')
# Out:
# churned                  0         1  diff_abs  diff_rel
# metodo_pagamento
# credito           0.507920  0.516237 -0.008317  0.983889
# debito            0.282474  0.292273 -0.009800  0.966471
# venmo             0.209606  0.191489  0.018117  1.094608

# %%
resumo_categorica('chamados_suporte')
# Out:
# churned                  0         1  diff_abs  diff_rel
# chamados_suporte
# alguns            0.199214  0.195969  0.003246  1.016562
# muito frequente   0.201622  0.206047 -0.004425  0.978525
# muitos            0.204283  0.185890  0.018393  1.098946
# nenhum            0.200228  0.200448 -0.000220  0.998903
# poucos            0.194652  0.211646 -0.016994  0.919706

# %%
from scipy.stats import chi2_contingency

def resumo_categorica_global(var, df=df_analise, target=target):
    # Crosstab absoluta (para chi²)
    tabela_abs = pd.crosstab(df[var], df[target])

    # Crosstab relativa (para diff)
    tabela_rel = pd.crosstab(df[var], df[target], normalize='columns')

    diff_abs = (tabela_rel[0] - tabela_rel[1]).abs().max()
    diff_rel = (tabela_rel[0] / tabela_rel[1]).apply(lambda x: max(x, 1/x)).max()

    chi2, p, _, _ = chi2_contingency(tabela_abs)

    return pd.Series({
        'max_diff_abs': diff_abs,
        'max_diff_rel': diff_rel,
        'chi2': chi2,
        'p_value': p
    })

# %%
resumo_final = (
    pd.DataFrame(
        {var: resumo_categorica_global(var) for var in df_analise.columns[:-1]}
    )
    .T
    .sort_values('chi2', ascending=False)
)

resumo_final
# Out:
#                   max_diff_abs  max_diff_rel      chi2   p_value
# plano_pagamento       0.030569      1.108026  3.522270  0.060549
# chamados_suporte      0.018393      1.098946  2.640947  0.619587
# metodo_pagamento      0.018117      1.094608  1.648109  0.438650
# tipo_assinatura       0.013651      1.062836  0.906744  0.823800

# %%
df_analise_ohe = pd.get_dummies(df_analise[df_analise.columns[:-1]], drop_first=True)

arvore_cat = tree.DecisionTreeClassifier(
    random_state=42,
    max_depth=5,
    min_samples_leaf=50
)

arvore_cat.fit(df_analise_ohe, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=50, random_state=42)

# %%
feat_import_cat = (
    pd.Series(arvore_cat.feature_importances_, index=df_analise_ohe.columns)
    .sort_values(ascending=False)
)

feat_import_cat.head(15)
# Out:
# chamados_suporte_nenhum             0.236130
# metodo_pagamento_venmo              0.225729
# tipo_assinatura_familia premium     0.167685
# chamados_suporte_muitos             0.091855
# tipo_assinatura_premium             0.083203
# plano_pagamento_mensal              0.081799
# chamados_suporte_muito frequente    0.075031
# metodo_pagamento_debito             0.030695
# tipo_assinatura_estudante           0.007875
# chamados_suporte_poucos             0.000000
# dtype: float64

# %%
feat_import_cat_grouped = (
    feat_import_cat
    .groupby(lambda x: x.rsplit('_',1)[0])
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)

feat_import_cat_grouped['acumulada'] = feat_import_cat_grouped[0].cumsum()
feat_import_cat_grouped
# Out:
#               index         0  acumulada
# 0  chamados_suporte  0.403015   0.403015
# 1   tipo_assinatura  0.258763   0.661778
# 2  metodo_pagamento  0.256424   0.918201
# 3   plano_pagamento  0.081799   1.000000

# %%
#best_features = (feat_import_num[feat_import_num['acumulada'] < 0.99]['index'].tolist()
#                + feat_import_cat_grouped[feat_import_cat_grouped['acumulada'] < 0.99]['index'].tolist())
best_features = feat_import_num[feat_import_num['acumulada'] < 0.99]['index'].tolist()

# %%
best_features
# Out:
# ['taxa_musicas_unicas',
#  'tempo_medio_sessao',
#  'horas_semanais',
#  'data_inscricao',
#  'taxa_skip_musica',
#  'num_amigos_plataforma',
#  'musicas_unicas_semana',
#  'musicas_tocadas_semana',
#  'idade',
#  'num_playlists_compartilhadas',
#  'log_notificacoes',
#  'num_playlists_criadas',
#  'notificacoes_clicadas',
#  'num_artistas_favoritos']

# %%
# MODIFY
# Discretização
tree_discretization = discretisation.DecisionTreeDiscretiser(variables=best_features,
                                                             regression=False,
                                                             bin_output="bin_number",
                                                             cv=3
                                                             )

# OneHot

onehot = encoding.OneHotEncoder(variables=best_features, ignore_format=True)

# %%
# MODEL
# Modelos -- Regressão Logistica
reg = linear_model.LogisticRegression(penalty=None,
                                      random_state=42
                                      )

# %%
# Modelos -- Random Forest
rf = RandomForestClassifier(random_state=42,
                            min_samples_leaf=20,
                            n_jobs=2,
                            n_estimators=10000)

# %%
# Criando pipeline
model_pipeline = Pipeline(
    steps=[
        ('Discretizar',tree_discretization),
        ('OneHot',onehot),
        ('Model',reg)
    ])

model_pipeline.fit(X_train[best_features],y_train)
# Out:
# Pipeline(steps=[('Discretizar',
#                  DecisionTreeDiscretiser(bin_output='bin_number',
#                                          regression=False,
#                                          variables=['taxa_musicas_unicas',
#                                                     'tempo_medio_sessao',
#                                                     'horas_semanais',
#                                                     'data_inscricao',
#                                                     'taxa_skip_musica',
#                                                     'num_amigos_plataforma',
#                                                     'musicas_unicas_semana',
#                                                     'musicas_tocadas_semana',
#                                                     'idade',
#                                                     'num_playlists_compartilhadas',
#                                                     'log_notificacoes',
#                                                     'num_playlists_c...
#                                variables=['taxa_musicas_unicas',
#                                           'tempo_medio_sessao',
#                                           'horas_semanais', 'data_inscricao',
#                                           'taxa_skip_musica',
#                                           'num_amigos_plataforma',
#                                           'musicas_unicas_semana',
#                                           'musicas_tocadas_semana', 'idade',
#                                           'num_playlists_compartilhadas',
#                                           'log_notificacoes',
#                                           'num_playlists_criadas',
#                                           'notificacoes_clicadas',
#                                           'num_artistas_favoritos'])),
#                 ('Model', LogisticRegression(penalty=None, random_state=42))])

# %%
y_train_predict = model_pipeline.predict(X_train[best_features])
y_train_proba = model_pipeline.predict_proba(X_train[best_features])[:,1]

acc_train = metrics.accuracy_score(y_train,y_train_predict)
auc_train = metrics.roc_auc_score(y_train, y_train_proba)
roc_train = metrics.roc_curve(y_train, y_train_proba)
print("Acurácia Treino:", acc_train)
print("AUC Treino:", auc_train)
print(f"Predições positivas treino: {y_train_predict.sum()} de {len(y_train)} ({y_train_predict.mean():.2%})")
print(f"Taxa real churn treino: {y_train.mean():.2%}")
# Out:
# Acurácia Treino: 0.8985655737704918
# AUC Treino: 0.5701398662033363
# Predições positivas treino: 2 de 8784 (0.02%)
# Taxa real churn treino: 10.17%

# %%
X_test = criar_features(X_test)

y_test_predict = model_pipeline.predict(X_test[best_features])
y_test_proba = model_pipeline.predict_proba(X_test[best_features])[:,1]

acc_test = metrics.accuracy_score(y_test,y_test_predict)
auc_test = metrics.roc_auc_score(y_test, y_test_proba)
roc_test = metrics.roc_curve(y_test, y_test_proba)
print("Acurácia Teste:", acc_test)
print("AUC Teste:", auc_test)
print(f"Predições positivas teste: {y_test_predict.sum()} de {len(y_test)} ({y_test_predict.mean():.2%})")
print(f"Taxa real churn teste: {y_test.mean():.2%}")
# Out:
# Acurácia Teste: 0.8979963570127505
# AUC Teste: 0.4610947340668532
# Predições positivas teste: 1 de 2196 (0.05%)
# Taxa real churn teste: 10.15%

# %%
oot = criar_features(oot)

oot_predict = model_pipeline.predict(oot[best_features])
oot_proba = model_pipeline.predict_proba(oot[best_features])[:,1]

acc_oot = metrics.accuracy_score(oot[target],oot_predict)
auc_oot = metrics.roc_auc_score(oot[target], oot_proba)
roc_oot = metrics.roc_curve(oot[target], oot_proba)
print("Acurácia oot:", acc_oot)
print("AUC oot:", auc_oot)
print(f"Predições positivas teste: {oot_predict.sum()} de {len(y_test)} ({oot_predict.mean():.2%})")
print(f"Taxa real churn teste: {y_test.mean():.2%}")
# Out:
# Acurácia oot: 0.9098684210526315
# AUC oot: 0.49442658770999254
# Predições positivas teste: 0 de 2196 (0.00%)
# Taxa real churn teste: 10.15%

# %%
plt.plot(roc_train[0], roc_train[1])
plt.plot(roc_test[0], roc_test[1])
plt.plot(roc_oot[0], roc_oot[1])
plt.grid(True)
plt.title("Curva ROC")
plt.legend([
    f"Treino: {100*auc_train:.2f}",
    f"Teste: {100*auc_test:.2f}",
    f"Out-of-Time: {100*auc_oot:.2f}"
])

# %%
model_pipeline = Pipeline(
    steps=[
        ('Discretizar',tree_discretization),
        ('OneHot',onehot),
        ('Model',rf)
    ])

model_pipeline.fit(X_train[best_features],y_train)
# Out:
# Pipeline(steps=[('Discretizar',
#                  DecisionTreeDiscretiser(bin_output='bin_number',
#                                          regression=False,
#                                          variables=['taxa_musicas_unicas',
#                                                     'tempo_medio_sessao',
#                                                     'horas_semanais',
#                                                     'data_inscricao',
#                                                     'taxa_skip_musica',
#                                                     'num_amigos_plataforma',
#                                                     'musicas_unicas_semana',
#                                                     'musicas_tocadas_semana',
#                                                     'idade',
#                                                     'num_playlists_compartilhadas',
#                                                     'log_notificacoes',
#                                                     'num_playlists_c...
#                                           'horas_semanais', 'data_inscricao',
#                                           'taxa_skip_musica',
#                                           'num_amigos_plataforma',
#                                           'musicas_unicas_semana',
#                                           'musicas_tocadas_semana', 'idade',
#                                           'num_playlists_compartilhadas',
#                                           'log_notificacoes',
#                                           'num_playlists_criadas',
#                                           'notificacoes_clicadas',
#                                           'num_artistas_favoritos'])),
#                 ('Model',
#                  RandomForestClassifier(min_samples_leaf=20, n_estimators=10000,
#                                         n_jobs=2, random_state=42))])

# %%
y_train_predict = model_pipeline.predict(X_train[best_features])
y_train_proba = model_pipeline.predict_proba(X_train[best_features])[:,1]

acc_train = metrics.accuracy_score(y_train,y_train_predict)
auc_train = metrics.roc_auc_score(y_train, y_train_proba)
roc_train = metrics.roc_curve(y_train, y_train_proba)
print("Acurácia Treino:", acc_train)
print("AUC Treino:", auc_train)
print(f"Predições positivas treino: {y_train_predict.sum()} de {len(y_train)} ({y_train_predict.mean():.2%})")
print(f"Taxa real churn treino: {y_train.mean():.2%}")
# Out:
# Acurácia Treino: 0.8983378870673953
# AUC Treino: 0.5837045137535313
# Predições positivas treino: 0 de 8784 (0.00%)
# Taxa real churn treino: 10.17%

# %%
#X_test = criar_features(X_test)

y_test_predict = model_pipeline.predict(X_test[best_features])
y_test_proba = model_pipeline.predict_proba(X_test[best_features])[:,1]

acc_test = metrics.accuracy_score(y_test,y_test_predict)
auc_test = metrics.roc_auc_score(y_test, y_test_proba)
roc_test = metrics.roc_curve(y_test, y_test_proba)
print("Acurácia Teste:", acc_test)
print("AUC Teste:", auc_test)
print(f"Predições positivas teste: {y_test_predict.sum()} de {len(y_test)} ({y_test_predict.mean():.2%})")
print(f"Taxa real churn teste: {y_test.mean():.2%}")
# Out:
# Acurácia Teste: 0.8984517304189436
# AUC Teste: 0.4686848690505682
# Predições positivas teste: 0 de 2196 (0.00%)
# Taxa real churn teste: 10.15%

# %%
#oot = criar_features(oot)

oot_predict = model_pipeline.predict(oot[best_features])
oot_proba = model_pipeline.predict_proba(oot[best_features])[:,1]

acc_oot = metrics.accuracy_score(oot[target],oot_predict)
auc_oot = metrics.roc_auc_score(oot[target], oot_proba)
roc_oot = metrics.roc_curve(oot[target], oot_proba)
print("Acurácia oot:", acc_oot)
print("AUC oot:", auc_oot)
print(f"Predições positivas teste: {oot_predict.sum()} de {len(y_test)} ({oot_predict.mean():.2%})")
print(f"Taxa real churn teste: {y_test.mean():.2%}")
# Out:
# Acurácia oot: 0.9098684210526315
# AUC oot: 0.4867314786959482
# Predições positivas teste: 0 de 2196 (0.00%)
# Taxa real churn teste: 10.15%

# %%
plt.plot(roc_train[0], roc_train[1])
plt.plot(roc_test[0], roc_test[1])
plt.plot(roc_oot[0], roc_oot[1])
plt.grid(True)
plt.title("Curva ROC")
plt.legend([
    f"Treino: {100*auc_train:.2f}",
    f"Teste: {100*auc_test:.2f}",
    f"Out-of-Time: {100*auc_oot:.2f}"
])
